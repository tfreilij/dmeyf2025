# %%
# %pip install duckdb
# %pip install jupysql
# %pip install duckdb-engine
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.3/137.3 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 3.2 MB/s eta 0:00:00
# ...

# %%
import duckdb
import pandas as pd

# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb://

# %%
from google.colab import drive
drive.mount('/content/drive')

dataset_path = '/content/drive/MyDrive/maestria/dm-eyf/datos/'
dataset_fe_file = 'competencia_01.csv'
# Out:
# Mounted at /content/drive

# %%
# %%sql
# create or replace table competencia_01_fe as
# select
#     *
# from read_csv_auto("{{dataset_path + dataset_fe_file}}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# CREATE OR REPLACE TABLE competencia_01_fe AS
# SELECT
#   t1.*
#   , t1.active_quarter - lag(t1.active_quarter, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_active_quarter,
#   t1.active_quarter - lag(t1.active_quarter, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_active_quarter,
#   t1.mrentabilidad - lag(t1.mrentabilidad, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mrentabilidad,
#   t1.mrentabilidad - lag(t1.mrentabilidad, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mrentabilidad,
#   t1.mrentabilidad_annual - lag(t1.mrentabilidad_annual, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mrentabilidad_annual,
#   t1.mrentabilidad_annual - lag(t1.mrentabilidad_annual, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mrentabilidad_annual,
#   t1.mcomisiones - lag(t1.mcomisiones, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mcomisiones,
#   t1.mcomisiones - lag(t1.mcomisiones, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mcomisiones,
#   t1.mactivos_margen - lag(t1.mactivos_margen, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mactivos_margen,
#   t1.mactivos_margen - lag(t1.mactivos_margen, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mactivos_margen,
#   t1.mpasivos_margen - lag(t1.mpasivos_margen, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mpasivos_margen,
#   t1.mpasivos_margen - lag(t1.mpasivos_margen, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mpasivos_margen,
#   t1.cproductos - lag(t1.cproductos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cproductos,
#   t1.cproductos - lag(t1.cproductos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cproductos,
#   t1.ccuenta_corriente - lag(t1.ccuenta_corriente, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ccuenta_corriente,
#   t1.ccuenta_corriente - lag(t1.ccuenta_corriente, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ccuenta_corriente,
#   t1.mcuenta_corriente_adicional - lag(t1.mcuenta_corriente_adicional, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mcuenta_corriente_adicional,
#   t1.mcuenta_corriente_adicional - lag(t1.mcuenta_corriente_adicional, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mcuenta_corriente_adicional,
#   t1.mcuenta_corriente - lag(t1.mcuenta_corriente, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mcuenta_corriente,
#   t1.mcuenta_corriente - lag(t1.mcuenta_corriente, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mcuenta_corriente,
#   t1.ccaja_ahorro - lag(t1.ccaja_ahorro, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ccaja_ahorro,
#   t1.ccaja_ahorro - lag(t1.ccaja_ahorro, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ccaja_ahorro,
#   t1.mcaja_ahorro - lag(t1.mcaja_ahorro, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mcaja_ahorro,
#   t1.mcaja_ahorro - lag(t1.mcaja_ahorro, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mcaja_ahorro,
#   t1.mcaja_ahorro_adicional - lag(t1.mcaja_ahorro_adicional, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mcaja_ahorro_adicional,
#   t1.mcaja_ahorro_adicional - lag(t1.mcaja_ahorro_adicional, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mcaja_ahorro_adicional,
#   t1.mcaja_ahorro_dolares - lag(t1.mcaja_ahorro_dolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mcaja_ahorro_dolares,
#   t1.mcaja_ahorro_dolares - lag(t1.mcaja_ahorro_dolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mcaja_ahorro_dolares,
#   t1.cdescubierto_preacordado - lag(t1.cdescubierto_preacordado, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cdescubierto_preacordado,
#   t1.cdescubierto_preacordado - lag(t1.cdescubierto_preacordado, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cdescubierto_preacordado,
#   t1.mcuentas_saldo - lag(t1.mcuentas_saldo, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mcuentas_saldo,
#   t1.mcuentas_saldo - lag(t1.mcuentas_saldo, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mcuentas_saldo,
#   t1.ctarjeta_debito - lag(t1.ctarjeta_debito, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ctarjeta_debito,
#   t1.ctarjeta_debito - lag(t1.ctarjeta_debito, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ctarjeta_debito,
#   t1.ctarjeta_debito_transacciones - lag(t1.ctarjeta_debito_transacciones, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ctarjeta_debito_transacciones,
#   t1.ctarjeta_debito_transacciones - lag(t1.ctarjeta_debito_transacciones, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ctarjeta_debito_transacciones,
#   t1.mautoservicio - lag(t1.mautoservicio, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mautoservicio,
#   t1.mautoservicio - lag(t1.mautoservicio, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mautoservicio,
#   t1.ctarjeta_visa - lag(t1.ctarjeta_visa, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ctarjeta_visa,
#   t1.ctarjeta_visa - lag(t1.ctarjeta_visa, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ctarjeta_visa,
#   t1.ctarjeta_visa_transacciones - lag(t1.ctarjeta_visa_transacciones, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ctarjeta_visa_transacciones,
#   t1.ctarjeta_visa_transacciones - lag(t1.ctarjeta_visa_transacciones, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ctarjeta_visa_transacciones,
#   t1.mtarjeta_visa_consumo - lag(t1.mtarjeta_visa_consumo, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mtarjeta_visa_consumo,
#   t1.mtarjeta_visa_consumo - lag(t1.mtarjeta_visa_consumo, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mtarjeta_visa_consumo,
#   t1.ctarjeta_master - lag(t1.ctarjeta_master, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ctarjeta_master,
#   t1.ctarjeta_master - lag(t1.ctarjeta_master, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ctarjeta_master,
#   t1.ctarjeta_master_transacciones - lag(t1.ctarjeta_master_transacciones, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ctarjeta_master_transacciones,
#   t1.ctarjeta_master_transacciones - lag(t1.ctarjeta_master_transacciones, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ctarjeta_master_transacciones,
#   t1.mtarjeta_master_consumo - lag(t1.mtarjeta_master_consumo, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mtarjeta_master_consumo,
#   t1.mtarjeta_master_consumo - lag(t1.mtarjeta_master_consumo, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mtarjeta_master_consumo,
#   t1.cprestamos_personales - lag(t1.cprestamos_personales, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cprestamos_personales,
#   t1.cprestamos_personales - lag(t1.cprestamos_personales, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cprestamos_personales,
#   t1.mprestamos_personales - lag(t1.mprestamos_personales, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mprestamos_personales,
#   t1.mprestamos_personales - lag(t1.mprestamos_personales, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mprestamos_personales,
#   t1.cprestamos_prendarios - lag(t1.cprestamos_prendarios, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cprestamos_prendarios,
#   t1.cprestamos_prendarios - lag(t1.cprestamos_prendarios, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cprestamos_prendarios,
#   t1.mprestamos_prendarios - lag(t1.mprestamos_prendarios, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mprestamos_prendarios,
#   t1.mprestamos_prendarios - lag(t1.mprestamos_prendarios, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mprestamos_prendarios,
#   t1.mprestamos_hipotecarios - lag(t1.mprestamos_hipotecarios, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mprestamos_hipotecarios,
#   t1.mprestamos_hipotecarios - lag(t1.mprestamos_hipotecarios, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mprestamos_hipotecarios,
#   t1.cplazo_fijo - lag(t1.cplazo_fijo, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cplazo_fijo,
#   t1.cplazo_fijo - lag(t1.cplazo_fijo, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cplazo_fijo,
#   t1.mplazo_fijo_dolares - lag(t1.mplazo_fijo_dolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mplazo_fijo_dolares,
#   t1.mplazo_fijo_dolares - lag(t1.mplazo_fijo_dolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mplazo_fijo_dolares,
#   t1.mplazo_fijo_pesos - lag(t1.mplazo_fijo_pesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mplazo_fijo_pesos,
#   t1.mplazo_fijo_pesos - lag(t1.mplazo_fijo_pesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mplazo_fijo_pesos,
#   t1.cinversion1 - lag(t1.cinversion1, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cinversion1,
#   t1.cinversion1 - lag(t1.cinversion1, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cinversion1,
#   t1.minversion1_pesos - lag(t1.minversion1_pesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_minversion1_pesos,
#   t1.minversion1_pesos - lag(t1.minversion1_pesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_minversion1_pesos,
#   t1.minversion1_dolares - lag(t1.minversion1_dolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_minversion1_dolares,
#   t1.minversion1_dolares - lag(t1.minversion1_dolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_minversion1_dolares,
#   t1.cinversion2 - lag(t1.cinversion2, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cinversion2,
#   t1.cinversion2 - lag(t1.cinversion2, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cinversion2,
#   t1.minversion2 - lag(t1.minversion2, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_minversion2,
#   t1.minversion2 - lag(t1.minversion2, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_minversion2,
#   t1.ccaja_seguridad - lag(t1.ccaja_seguridad, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ccaja_seguridad,
#   t1.ccaja_seguridad - lag(t1.ccaja_seguridad, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ccaja_seguridad,
#   t1.cpayroll_trx - lag(t1.cpayroll_trx, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cpayroll_trx,
#   t1.cpayroll_trx - lag(t1.cpayroll_trx, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cpayroll_trx,
#   t1.mpayroll - lag(t1.mpayroll, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mpayroll,
#   t1.mpayroll - lag(t1.mpayroll, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mpayroll,
#   t1.mpayroll2 - lag(t1.mpayroll2, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mpayroll2,
#   t1.mpayroll2 - lag(t1.mpayroll2, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mpayroll2,
#   t1.cpayroll2_trx - lag(t1.cpayroll2_trx, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cpayroll2_trx,
#   t1.cpayroll2_trx - lag(t1.cpayroll2_trx, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cpayroll2_trx,
#   t1.ccuenta_debitos_automaticos - lag(t1.ccuenta_debitos_automaticos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ccuenta_debitos_automaticos,
#   t1.ccuenta_debitos_automaticos - lag(t1.ccuenta_debitos_automaticos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ccuenta_debitos_automaticos,
#   t1.mcuenta_debitos_automaticos - lag(t1.mcuenta_debitos_automaticos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mcuenta_debitos_automaticos,
#   t1.mcuenta_debitos_automaticos - lag(t1.mcuenta_debitos_automaticos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mcuenta_debitos_automaticos,
#   t1.ctarjeta_visa_debitos_automaticos - lag(t1.ctarjeta_visa_debitos_automaticos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ctarjeta_visa_debitos_automaticos,
#   t1.ctarjeta_visa_debitos_automaticos - lag(t1.ctarjeta_visa_debitos_automaticos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ctarjeta_visa_debitos_automaticos,
#   t1.mttarjeta_visa_debitos_automaticos - lag(t1.mttarjeta_visa_debitos_automaticos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mttarjeta_visa_debitos_automaticos,
#   t1.mttarjeta_visa_debitos_automaticos - lag(t1.mttarjeta_visa_debitos_automaticos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mttarjeta_visa_debitos_automaticos,
#   t1.ctarjeta_master_debitos_automaticos - lag(t1.ctarjeta_master_debitos_automaticos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ctarjeta_master_debitos_automaticos,
#   t1.ctarjeta_master_debitos_automaticos - lag(t1.ctarjeta_master_debitos_automaticos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ctarjeta_master_debitos_automaticos,
#   t1.mttarjeta_master_debitos_automaticos - lag(t1.mttarjeta_master_debitos_automaticos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mttarjeta_master_debitos_automaticos,
#   t1.mttarjeta_master_debitos_automaticos - lag(t1.mttarjeta_master_debitos_automaticos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mttarjeta_master_debitos_automaticos,
#   t1.cpagodeservicios - lag(t1.cpagodeservicios, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cpagodeservicios,
#   t1.cpagodeservicios - lag(t1.cpagodeservicios, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cpagodeservicios,
#   t1.mpagodeservicios - lag(t1.mpagodeservicios, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mpagodeservicios,
#   t1.mpagodeservicios - lag(t1.mpagodeservicios, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mpagodeservicios,
#   t1.cpagomiscuentas - lag(t1.cpagomiscuentas, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cpagomiscuentas,
#   t1.cpagomiscuentas - lag(t1.cpagomiscuentas, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cpagomiscuentas,
#   t1.mpagomiscuentas - lag(t1.mpagomiscuentas, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mpagomiscuentas,
#   t1.mpagomiscuentas - lag(t1.mpagomiscuentas, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mpagomiscuentas,
#   t1.ccajeros_propios_descuentos - lag(t1.ccajeros_propios_descuentos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ccajeros_propios_descuentos,
#   t1.ccajeros_propios_descuentos - lag(t1.ccajeros_propios_descuentos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ccajeros_propios_descuentos,
#   t1.mcajeros_propios_descuentos - lag(t1.mcajeros_propios_descuentos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mcajeros_propios_descuentos,
#   t1.mcajeros_propios_descuentos - lag(t1.mcajeros_propios_descuentos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mcajeros_propios_descuentos,
#   t1.ctarjeta_visa_descuentos - lag(t1.ctarjeta_visa_descuentos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ctarjeta_visa_descuentos,
#   t1.ctarjeta_visa_descuentos - lag(t1.ctarjeta_visa_descuentos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ctarjeta_visa_descuentos,
#   t1.mtarjeta_visa_descuentos - lag(t1.mtarjeta_visa_descuentos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mtarjeta_visa_descuentos,
#   t1.mtarjeta_visa_descuentos - lag(t1.mtarjeta_visa_descuentos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mtarjeta_visa_descuentos,
#   t1.ctarjeta_master_descuentos - lag(t1.ctarjeta_master_descuentos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ctarjeta_master_descuentos,
#   t1.ctarjeta_master_descuentos - lag(t1.ctarjeta_master_descuentos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ctarjeta_master_descuentos,
#   t1.mtarjeta_master_descuentos - lag(t1.mtarjeta_master_descuentos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mtarjeta_master_descuentos,
#   t1.mtarjeta_master_descuentos - lag(t1.mtarjeta_master_descuentos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mtarjeta_master_descuentos,
#   t1.ccomisiones_mantenimiento - lag(t1.ccomisiones_mantenimiento, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ccomisiones_mantenimiento,
#   t1.ccomisiones_mantenimiento - lag(t1.ccomisiones_mantenimiento, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ccomisiones_mantenimiento,
#   t1.mcomisiones_mantenimiento - lag(t1.mcomisiones_mantenimiento, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mcomisiones_mantenimiento,
#   t1.mcomisiones_mantenimiento - lag(t1.mcomisiones_mantenimiento, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mcomisiones_mantenimiento,
#   t1.ccomisiones_otras - lag(t1.ccomisiones_otras, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ccomisiones_otras,
#   t1.ccomisiones_otras - lag(t1.ccomisiones_otras, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ccomisiones_otras,
#   t1.mcomisiones_otras - lag(t1.mcomisiones_otras, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mcomisiones_otras,
#   t1.mcomisiones_otras - lag(t1.mcomisiones_otras, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mcomisiones_otras,
#   t1.cforex - lag(t1.cforex, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cforex,
#   t1.cforex - lag(t1.cforex, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cforex,
#   t1.cforex_buy - lag(t1.cforex_buy, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cforex_buy,
#   t1.cforex_buy - lag(t1.cforex_buy, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cforex_buy,
#   t1.mforex_buy - lag(t1.mforex_buy, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mforex_buy,
#   t1.mforex_buy - lag(t1.mforex_buy, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mforex_buy,
#   t1.cforex_sell - lag(t1.cforex_sell, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cforex_sell,
#   t1.cforex_sell - lag(t1.cforex_sell, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cforex_sell,
#   t1.mforex_sell - lag(t1.mforex_sell, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mforex_sell,
#   t1.mforex_sell - lag(t1.mforex_sell, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mforex_sell,
#   t1.ctransferencias_recibidas - lag(t1.ctransferencias_recibidas, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ctransferencias_recibidas,
#   t1.ctransferencias_recibidas - lag(t1.ctransferencias_recibidas, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ctransferencias_recibidas,
#   t1.mtransferencias_recibidas - lag(t1.mtransferencias_recibidas, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mtransferencias_recibidas,
#   t1.mtransferencias_recibidas - lag(t1.mtransferencias_recibidas, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mtransferencias_recibidas,
#   t1.ctransferencias_emitidas - lag(t1.ctransferencias_emitidas, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ctransferencias_emitidas,
#   t1.ctransferencias_emitidas - lag(t1.ctransferencias_emitidas, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ctransferencias_emitidas,
#   t1.mtransferencias_emitidas - lag(t1.mtransferencias_emitidas, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mtransferencias_emitidas,
#   t1.mtransferencias_emitidas - lag(t1.mtransferencias_emitidas, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mtransferencias_emitidas,
#   t1.cextraccion_autoservicio - lag(t1.cextraccion_autoservicio, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cextraccion_autoservicio,
#   t1.cextraccion_autoservicio - lag(t1.cextraccion_autoservicio, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cextraccion_autoservicio,
#   t1.mextraccion_autoservicio - lag(t1.mextraccion_autoservicio, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_mextraccion_autoservicio,
#   t1.mextraccion_autoservicio - lag(t1.mextraccion_autoservicio, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_mextraccion_autoservicio,
#   t1.tcallcenter - lag(t1.tcallcenter, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_tcallcenter,
#   t1.tcallcenter - lag(t1.tcallcenter, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_tcallcenter,
#   t1.ccallcenter_transacciones - lag(t1.ccallcenter_transacciones, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ccallcenter_transacciones,
#   t1.ccallcenter_transacciones - lag(t1.ccallcenter_transacciones, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ccallcenter_transacciones,
#   t1.chomebanking_transacciones - lag(t1.chomebanking_transacciones, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_chomebanking_transacciones,
#   t1.chomebanking_transacciones - lag(t1.chomebanking_transacciones, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_chomebanking_transacciones,
#   t1.ccajas_consultas - lag(t1.ccajas_consultas, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ccajas_consultas,
#   t1.ccajas_consultas - lag(t1.ccajas_consultas, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ccajas_consultas,
#   t1.ccajas_extracciones - lag(t1.ccajas_extracciones, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ccajas_extracciones,
#   t1.ccajas_extracciones - lag(t1.ccajas_extracciones, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ccajas_extracciones,
#   t1.ccajas_otras - lag(t1.ccajas_otras, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ccajas_otras,
#   t1.ccajas_otras - lag(t1.ccajas_otras, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ccajas_otras,
#   t1.catm_trx - lag(t1.catm_trx, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_catm_trx,
#   t1.catm_trx - lag(t1.catm_trx, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_catm_trx,
#   t1.matm - lag(t1.matm, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_matm,
#   t1.matm - lag(t1.matm, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_matm,
#   t1.ctrx_quarter - lag(t1.ctrx_quarter, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_ctrx_quarter,
#   t1.ctrx_quarter - lag(t1.ctrx_quarter, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_ctrx_quarter,
#   t1.cmobile_app_trx - lag(t1.cmobile_app_trx, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_cmobile_app_trx,
#   t1.cmobile_app_trx - lag(t1.cmobile_app_trx, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_cmobile_app_trx,
#   t1.Master_delinquency - lag(t1.Master_delinquency, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_delinquency,
#   t1.Master_delinquency - lag(t1.Master_delinquency, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_delinquency,
#   t1.Master_mfinanciacion_limite - lag(t1.Master_mfinanciacion_limite, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_mfinanciacion_limite,
#   t1.Master_mfinanciacion_limite - lag(t1.Master_mfinanciacion_limite, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_mfinanciacion_limite,
#   t1.Master_Fvencimiento - lag(t1.Master_Fvencimiento, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_Fvencimiento,
#   t1.Master_Fvencimiento - lag(t1.Master_Fvencimiento, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_Fvencimiento,
#   t1.Master_Finiciomora - lag(t1.Master_Finiciomora, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_Finiciomora,
#   t1.Master_Finiciomora - lag(t1.Master_Finiciomora, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_Finiciomora,
#   t1.Master_msaldototal - lag(t1.Master_msaldototal, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_msaldototal,
#   t1.Master_msaldototal - lag(t1.Master_msaldototal, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_msaldototal,
#   t1.Master_msaldopesos - lag(t1.Master_msaldopesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_msaldopesos,
#   t1.Master_msaldopesos - lag(t1.Master_msaldopesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_msaldopesos,
#   t1.Master_msaldodolares - lag(t1.Master_msaldodolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_msaldodolares,
#   t1.Master_msaldodolares - lag(t1.Master_msaldodolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_msaldodolares,
#   t1.Master_mconsumospesos - lag(t1.Master_mconsumospesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_mconsumospesos,
#   t1.Master_mconsumospesos - lag(t1.Master_mconsumospesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_mconsumospesos,
#   t1.Master_mconsumosdolares - lag(t1.Master_mconsumosdolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_mconsumosdolares,
#   t1.Master_mconsumosdolares - lag(t1.Master_mconsumosdolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_mconsumosdolares,
#   t1.Master_mlimitecompra - lag(t1.Master_mlimitecompra, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_mlimitecompra,
#   t1.Master_mlimitecompra - lag(t1.Master_mlimitecompra, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_mlimitecompra,
#   t1.Master_madelantopesos - lag(t1.Master_madelantopesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_madelantopesos,
#   t1.Master_madelantopesos - lag(t1.Master_madelantopesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_madelantopesos,
#   t1.Master_madelantodolares - lag(t1.Master_madelantodolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_madelantodolares,
#   t1.Master_madelantodolares - lag(t1.Master_madelantodolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_madelantodolares,
#   t1.Master_fultimo_cierre - lag(t1.Master_fultimo_cierre, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_fultimo_cierre,
#   t1.Master_fultimo_cierre - lag(t1.Master_fultimo_cierre, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_fultimo_cierre,
#   t1.Master_mpagado - lag(t1.Master_mpagado, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_mpagado,
#   t1.Master_mpagado - lag(t1.Master_mpagado, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_mpagado,
#   t1.Master_mpagospesos - lag(t1.Master_mpagospesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_mpagospesos,
#   t1.Master_mpagospesos - lag(t1.Master_mpagospesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_mpagospesos,
#   t1.Master_mpagosdolares - lag(t1.Master_mpagosdolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_mpagosdolares,
#   t1.Master_mpagosdolares - lag(t1.Master_mpagosdolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_mpagosdolares,
#   t1.Master_mconsumototal - lag(t1.Master_mconsumototal, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_mconsumototal,
#   t1.Master_mconsumototal - lag(t1.Master_mconsumototal, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_mconsumototal,
#   t1.Master_cconsumos - lag(t1.Master_cconsumos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_cconsumos,
#   t1.Master_cconsumos - lag(t1.Master_cconsumos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_cconsumos,
#   t1.Master_cadelantosefectivo - lag(t1.Master_cadelantosefectivo, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_cadelantosefectivo,
#   t1.Master_cadelantosefectivo - lag(t1.Master_cadelantosefectivo, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_cadelantosefectivo,
#   t1.Master_mpagominimo - lag(t1.Master_mpagominimo, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Master_mpagominimo,
#   t1.Master_mpagominimo - lag(t1.Master_mpagominimo, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Master_mpagominimo,
#   t1.Visa_delinquency - lag(t1.Visa_delinquency, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_delinquency,
#   t1.Visa_delinquency - lag(t1.Visa_delinquency, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_delinquency,
#   t1.Visa_mfinanciacion_limite - lag(t1.Visa_mfinanciacion_limite, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_mfinanciacion_limite,
#   t1.Visa_mfinanciacion_limite - lag(t1.Visa_mfinanciacion_limite, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_mfinanciacion_limite,
#   t1.Visa_msaldototal - lag(t1.Visa_msaldototal, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_msaldototal,
#   t1.Visa_msaldototal - lag(t1.Visa_msaldototal, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_msaldototal,
#   t1.Visa_msaldopesos - lag(t1.Visa_msaldopesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_msaldopesos,
#   t1.Visa_msaldopesos - lag(t1.Visa_msaldopesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_msaldopesos,
#   t1.Visa_msaldodolares - lag(t1.Visa_msaldodolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_msaldodolares,
#   t1.Visa_msaldodolares - lag(t1.Visa_msaldodolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_msaldodolares,
#   t1.Visa_mconsumospesos - lag(t1.Visa_mconsumospesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_mconsumospesos,
#   t1.Visa_mconsumospesos - lag(t1.Visa_mconsumospesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_mconsumospesos,
#   t1.Visa_mconsumosdolares - lag(t1.Visa_mconsumosdolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_mconsumosdolares,
#   t1.Visa_mconsumosdolares - lag(t1.Visa_mconsumosdolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_mconsumosdolares,
#   t1.Visa_mlimitecompra - lag(t1.Visa_mlimitecompra, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_mlimitecompra,
#   t1.Visa_mlimitecompra - lag(t1.Visa_mlimitecompra, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_mlimitecompra,
#   t1.Visa_madelantopesos - lag(t1.Visa_madelantopesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_madelantopesos,
#   t1.Visa_madelantopesos - lag(t1.Visa_madelantopesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_madelantopesos,
#   t1.Visa_madelantodolares - lag(t1.Visa_madelantodolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_madelantodolares,
#   t1.Visa_madelantodolares - lag(t1.Visa_madelantodolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_madelantodolares,
#   t1.Visa_fultimo_cierre - lag(t1.Visa_fultimo_cierre, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_fultimo_cierre,
#   t1.Visa_fultimo_cierre - lag(t1.Visa_fultimo_cierre, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_fultimo_cierre,
#   t1.Visa_mpagado - lag(t1.Visa_mpagado, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_mpagado,
#   t1.Visa_mpagado - lag(t1.Visa_mpagado, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_mpagado,
#   t1.Visa_mpagospesos - lag(t1.Visa_mpagospesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_mpagospesos,
#   t1.Visa_mpagospesos - lag(t1.Visa_mpagospesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_mpagospesos,
#   t1.Visa_mpagosdolares - lag(t1.Visa_mpagosdolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_mpagosdolares,
#   t1.Visa_mpagosdolares - lag(t1.Visa_mpagosdolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_mpagosdolares,
#   t1.Visa_mconsumototal - lag(t1.Visa_mconsumototal, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_mconsumototal,
#   t1.Visa_mconsumototal - lag(t1.Visa_mconsumototal, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_mconsumototal,
#   t1.Visa_cconsumos - lag(t1.Visa_cconsumos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_1_Visa_cconsumos,
#   t1.Visa_cconsumos - lag(t1.Visa_cconsumos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes) as delta_2_Visa_cconsumos,
#   (t1.active_quarter - lag(t1.active_quarter, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.active_quarter - lag(t1.active_quarter, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_active_quarter,
#   (t1.cliente_vip - lag(t1.cliente_vip, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cliente_vip - lag(t1.cliente_vip, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cliente_vip,
#   (t1.internet - lag(t1.internet, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.internet - lag(t1.internet, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_internet,
#   (t1.cliente_edad - lag(t1.cliente_edad, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cliente_edad - lag(t1.cliente_edad, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cliente_edad,
#   (t1.cliente_antiguedad - lag(t1.cliente_antiguedad, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cliente_antiguedad - lag(t1.cliente_antiguedad, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cliente_antiguedad,
#   (t1.mrentabilidad - lag(t1.mrentabilidad, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mrentabilidad - lag(t1.mrentabilidad, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mrentabilidad,
#   (t1.mrentabilidad_annual - lag(t1.mrentabilidad_annual, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mrentabilidad_annual - lag(t1.mrentabilidad_annual, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mrentabilidad_annual,
#   (t1.mcomisiones - lag(t1.mcomisiones, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mcomisiones - lag(t1.mcomisiones, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mcomisiones,
#   (t1.mactivos_margen - lag(t1.mactivos_margen, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mactivos_margen - lag(t1.mactivos_margen, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mactivos_margen,
#   (t1.mpasivos_margen - lag(t1.mpasivos_margen, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mpasivos_margen - lag(t1.mpasivos_margen, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mpasivos_margen,
#   (t1.cproductos - lag(t1.cproductos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cproductos - lag(t1.cproductos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cproductos,
#   (t1.ccuenta_corriente - lag(t1.ccuenta_corriente, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ccuenta_corriente - lag(t1.ccuenta_corriente, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ccuenta_corriente,
#   (t1.mcuenta_corriente_adicional - lag(t1.mcuenta_corriente_adicional, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mcuenta_corriente_adicional - lag(t1.mcuenta_corriente_adicional, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mcuenta_corriente_adicional,
#   (t1.mcuenta_corriente - lag(t1.mcuenta_corriente, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mcuenta_corriente - lag(t1.mcuenta_corriente, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mcuenta_corriente,
#   (t1.ccaja_ahorro - lag(t1.ccaja_ahorro, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ccaja_ahorro - lag(t1.ccaja_ahorro, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ccaja_ahorro,
#   (t1.mcaja_ahorro - lag(t1.mcaja_ahorro, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mcaja_ahorro - lag(t1.mcaja_ahorro, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mcaja_ahorro,
#   (t1.mcaja_ahorro_adicional - lag(t1.mcaja_ahorro_adicional, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mcaja_ahorro_adicional - lag(t1.mcaja_ahorro_adicional, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mcaja_ahorro_adicional,
#   (t1.mcaja_ahorro_dolares - lag(t1.mcaja_ahorro_dolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mcaja_ahorro_dolares - lag(t1.mcaja_ahorro_dolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mcaja_ahorro_dolares,
#   (t1.cdescubierto_preacordado - lag(t1.cdescubierto_preacordado, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cdescubierto_preacordado - lag(t1.cdescubierto_preacordado, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cdescubierto_preacordado,
#   (t1.mcuentas_saldo - lag(t1.mcuentas_saldo, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mcuentas_saldo - lag(t1.mcuentas_saldo, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mcuentas_saldo,
#   (t1.ctarjeta_debito - lag(t1.ctarjeta_debito, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ctarjeta_debito - lag(t1.ctarjeta_debito, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ctarjeta_debito,
#   (t1.ctarjeta_debito_transacciones - lag(t1.ctarjeta_debito_transacciones, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ctarjeta_debito_transacciones - lag(t1.ctarjeta_debito_transacciones, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ctarjeta_debito_transacciones,
#   (t1.mautoservicio - lag(t1.mautoservicio, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mautoservicio - lag(t1.mautoservicio, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mautoservicio,
#   (t1.ctarjeta_visa - lag(t1.ctarjeta_visa, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ctarjeta_visa - lag(t1.ctarjeta_visa, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ctarjeta_visa,
#   (t1.ctarjeta_visa_transacciones - lag(t1.ctarjeta_visa_transacciones, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ctarjeta_visa_transacciones - lag(t1.ctarjeta_visa_transacciones, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ctarjeta_visa_transacciones,
#   (t1.mtarjeta_visa_consumo - lag(t1.mtarjeta_visa_consumo, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mtarjeta_visa_consumo - lag(t1.mtarjeta_visa_consumo, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mtarjeta_visa_consumo,
#   (t1.ctarjeta_master - lag(t1.ctarjeta_master, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ctarjeta_master - lag(t1.ctarjeta_master, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ctarjeta_master,
#   (t1.ctarjeta_master_transacciones - lag(t1.ctarjeta_master_transacciones, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ctarjeta_master_transacciones - lag(t1.ctarjeta_master_transacciones, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ctarjeta_master_transacciones,
#   (t1.mtarjeta_master_consumo - lag(t1.mtarjeta_master_consumo, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mtarjeta_master_consumo - lag(t1.mtarjeta_master_consumo, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mtarjeta_master_consumo,
#   (t1.cprestamos_personales - lag(t1.cprestamos_personales, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cprestamos_personales - lag(t1.cprestamos_personales, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cprestamos_personales,
#   (t1.mprestamos_personales - lag(t1.mprestamos_personales, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mprestamos_personales - lag(t1.mprestamos_personales, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mprestamos_personales,
#   (t1.cprestamos_prendarios - lag(t1.cprestamos_prendarios, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cprestamos_prendarios - lag(t1.cprestamos_prendarios, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cprestamos_prendarios,
#   (t1.mprestamos_prendarios - lag(t1.mprestamos_prendarios, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mprestamos_prendarios - lag(t1.mprestamos_prendarios, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mprestamos_prendarios,
#   (t1.cprestamos_hipotecarios - lag(t1.cprestamos_hipotecarios, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cprestamos_hipotecarios - lag(t1.cprestamos_hipotecarios, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cprestamos_hipotecarios,
#   (t1.mprestamos_hipotecarios - lag(t1.mprestamos_hipotecarios, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mprestamos_hipotecarios - lag(t1.mprestamos_hipotecarios, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mprestamos_hipotecarios,
#   (t1.cplazo_fijo - lag(t1.cplazo_fijo, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cplazo_fijo - lag(t1.cplazo_fijo, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cplazo_fijo,
#   (t1.mplazo_fijo_dolares - lag(t1.mplazo_fijo_dolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mplazo_fijo_dolares - lag(t1.mplazo_fijo_dolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mplazo_fijo_dolares,
#   (t1.mplazo_fijo_pesos - lag(t1.mplazo_fijo_pesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mplazo_fijo_pesos - lag(t1.mplazo_fijo_pesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mplazo_fijo_pesos,
#   (t1.cinversion1 - lag(t1.cinversion1, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cinversion1 - lag(t1.cinversion1, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cinversion1,
#   (t1.minversion1_pesos - lag(t1.minversion1_pesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.minversion1_pesos - lag(t1.minversion1_pesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_minversion1_pesos,
#   (t1.minversion1_dolares - lag(t1.minversion1_dolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.minversion1_dolares - lag(t1.minversion1_dolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_minversion1_dolares,
#   (t1.cinversion2 - lag(t1.cinversion2, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cinversion2 - lag(t1.cinversion2, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cinversion2,
#   (t1.minversion2 - lag(t1.minversion2, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.minversion2 - lag(t1.minversion2, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_minversion2,
#   (t1.ccaja_seguridad - lag(t1.ccaja_seguridad, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ccaja_seguridad - lag(t1.ccaja_seguridad, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ccaja_seguridad,
#   (t1.cpayroll_trx - lag(t1.cpayroll_trx, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cpayroll_trx - lag(t1.cpayroll_trx, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cpayroll_trx,
#   (t1.mpayroll - lag(t1.mpayroll, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mpayroll - lag(t1.mpayroll, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mpayroll,
#   (t1.mpayroll2 - lag(t1.mpayroll2, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mpayroll2 - lag(t1.mpayroll2, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mpayroll2,
#   (t1.cpayroll2_trx - lag(t1.cpayroll2_trx, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cpayroll2_trx - lag(t1.cpayroll2_trx, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cpayroll2_trx,
#   (t1.ccuenta_debitos_automaticos - lag(t1.ccuenta_debitos_automaticos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ccuenta_debitos_automaticos - lag(t1.ccuenta_debitos_automaticos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ccuenta_debitos_automaticos,
#   (t1.mcuenta_debitos_automaticos - lag(t1.mcuenta_debitos_automaticos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mcuenta_debitos_automaticos - lag(t1.mcuenta_debitos_automaticos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mcuenta_debitos_automaticos,
#   (t1.ctarjeta_visa_debitos_automaticos - lag(t1.ctarjeta_visa_debitos_automaticos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ctarjeta_visa_debitos_automaticos - lag(t1.ctarjeta_visa_debitos_automaticos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ctarjeta_visa_debitos_automaticos,
#   (t1.mttarjeta_visa_debitos_automaticos - lag(t1.mttarjeta_visa_debitos_automaticos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mttarjeta_visa_debitos_automaticos - lag(t1.mttarjeta_visa_debitos_automaticos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mttarjeta_visa_debitos_automaticos,
#   (t1.ctarjeta_master_debitos_automaticos - lag(t1.ctarjeta_master_debitos_automaticos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ctarjeta_master_debitos_automaticos - lag(t1.ctarjeta_master_debitos_automaticos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ctarjeta_master_debitos_automaticos,
#   (t1.mttarjeta_master_debitos_automaticos - lag(t1.mttarjeta_master_debitos_automaticos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mttarjeta_master_debitos_automaticos - lag(t1.mttarjeta_master_debitos_automaticos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mttarjeta_master_debitos_automaticos,
#   (t1.cpagodeservicios - lag(t1.cpagodeservicios, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cpagodeservicios - lag(t1.cpagodeservicios, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cpagodeservicios,
#   (t1.mpagodeservicios - lag(t1.mpagodeservicios, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mpagodeservicios - lag(t1.mpagodeservicios, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mpagodeservicios,
#   (t1.cpagomiscuentas - lag(t1.cpagomiscuentas, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cpagomiscuentas - lag(t1.cpagomiscuentas, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cpagomiscuentas,
#   (t1.mpagomiscuentas - lag(t1.mpagomiscuentas, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mpagomiscuentas - lag(t1.mpagomiscuentas, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mpagomiscuentas,
#   (t1.ccajeros_propios_descuentos - lag(t1.ccajeros_propios_descuentos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ccajeros_propios_descuentos - lag(t1.ccajeros_propios_descuentos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ccajeros_propios_descuentos,
#   (t1.mcajeros_propios_descuentos - lag(t1.mcajeros_propios_descuentos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mcajeros_propios_descuentos - lag(t1.mcajeros_propios_descuentos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mcajeros_propios_descuentos,
#   (t1.ctarjeta_visa_descuentos - lag(t1.ctarjeta_visa_descuentos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ctarjeta_visa_descuentos - lag(t1.ctarjeta_visa_descuentos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ctarjeta_visa_descuentos,
#   (t1.mtarjeta_visa_descuentos - lag(t1.mtarjeta_visa_descuentos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mtarjeta_visa_descuentos - lag(t1.mtarjeta_visa_descuentos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mtarjeta_visa_descuentos,
#   (t1.ctarjeta_master_descuentos - lag(t1.ctarjeta_master_descuentos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ctarjeta_master_descuentos - lag(t1.ctarjeta_master_descuentos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ctarjeta_master_descuentos,
#   (t1.mtarjeta_master_descuentos - lag(t1.mtarjeta_master_descuentos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mtarjeta_master_descuentos - lag(t1.mtarjeta_master_descuentos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mtarjeta_master_descuentos,
#   (t1.ccomisiones_mantenimiento - lag(t1.ccomisiones_mantenimiento, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ccomisiones_mantenimiento - lag(t1.ccomisiones_mantenimiento, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ccomisiones_mantenimiento,
#   (t1.mcomisiones_mantenimiento - lag(t1.mcomisiones_mantenimiento, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mcomisiones_mantenimiento - lag(t1.mcomisiones_mantenimiento, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mcomisiones_mantenimiento,
#   (t1.ccomisiones_otras - lag(t1.ccomisiones_otras, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ccomisiones_otras - lag(t1.ccomisiones_otras, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ccomisiones_otras,
#   (t1.mcomisiones_otras - lag(t1.mcomisiones_otras, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mcomisiones_otras - lag(t1.mcomisiones_otras, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mcomisiones_otras,
#   (t1.cforex - lag(t1.cforex, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cforex - lag(t1.cforex, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cforex,
#   (t1.cforex_buy - lag(t1.cforex_buy, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cforex_buy - lag(t1.cforex_buy, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cforex_buy,
#   (t1.mforex_buy - lag(t1.mforex_buy, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mforex_buy - lag(t1.mforex_buy, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mforex_buy,
#   (t1.cforex_sell - lag(t1.cforex_sell, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cforex_sell - lag(t1.cforex_sell, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cforex_sell,
#   (t1.mforex_sell - lag(t1.mforex_sell, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mforex_sell - lag(t1.mforex_sell, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mforex_sell,
#   (t1.ctransferencias_recibidas - lag(t1.ctransferencias_recibidas, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ctransferencias_recibidas - lag(t1.ctransferencias_recibidas, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ctransferencias_recibidas,
#   (t1.mtransferencias_recibidas - lag(t1.mtransferencias_recibidas, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mtransferencias_recibidas - lag(t1.mtransferencias_recibidas, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mtransferencias_recibidas,
#   (t1.ctransferencias_emitidas - lag(t1.ctransferencias_emitidas, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ctransferencias_emitidas - lag(t1.ctransferencias_emitidas, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ctransferencias_emitidas,
#   (t1.mtransferencias_emitidas - lag(t1.mtransferencias_emitidas, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mtransferencias_emitidas - lag(t1.mtransferencias_emitidas, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mtransferencias_emitidas,
#   (t1.cextraccion_autoservicio - lag(t1.cextraccion_autoservicio, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cextraccion_autoservicio - lag(t1.cextraccion_autoservicio, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cextraccion_autoservicio,
#   (t1.mextraccion_autoservicio - lag(t1.mextraccion_autoservicio, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.mextraccion_autoservicio - lag(t1.mextraccion_autoservicio, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_mextraccion_autoservicio,
#   (t1.chomebanking_transacciones - lag(t1.chomebanking_transacciones, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.chomebanking_transacciones - lag(t1.chomebanking_transacciones, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_chomebanking_transacciones,
#   (t1.ccajas_extracciones - lag(t1.ccajas_extracciones, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ccajas_extracciones - lag(t1.ccajas_extracciones, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ccajas_extracciones,
#   (t1.ccajas_otras - lag(t1.ccajas_otras, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ccajas_otras - lag(t1.ccajas_otras, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ccajas_otras,
#   (t1.catm_trx - lag(t1.catm_trx, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.catm_trx - lag(t1.catm_trx, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_catm_trx,
#   (t1.matm - lag(t1.matm, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.matm - lag(t1.matm, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_matm,
#   (t1.ctrx_quarter - lag(t1.ctrx_quarter, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.ctrx_quarter - lag(t1.ctrx_quarter, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_ctrx_quarter,
#   (t1.cmobile_app_trx - lag(t1.cmobile_app_trx, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.cmobile_app_trx - lag(t1.cmobile_app_trx, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_cmobile_app_trx,
#   (t1.Master_delinquency - lag(t1.Master_delinquency, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_delinquency - lag(t1.Master_delinquency, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_delinquency,
#   (t1.Master_mfinanciacion_limite - lag(t1.Master_mfinanciacion_limite, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_mfinanciacion_limite - lag(t1.Master_mfinanciacion_limite, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_mfinanciacion_limite,
#   (t1.Master_Fvencimiento - lag(t1.Master_Fvencimiento, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_Fvencimiento - lag(t1.Master_Fvencimiento, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_Fvencimiento,
#   (t1.Master_Finiciomora - lag(t1.Master_Finiciomora, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_Finiciomora - lag(t1.Master_Finiciomora, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_Finiciomora,
#   (t1.Master_msaldototal - lag(t1.Master_msaldototal, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_msaldototal - lag(t1.Master_msaldototal, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_msaldototal,
#   (t1.Master_msaldopesos - lag(t1.Master_msaldopesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_msaldopesos - lag(t1.Master_msaldopesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_msaldopesos,
#   (t1.Master_msaldodolares - lag(t1.Master_msaldodolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_msaldodolares - lag(t1.Master_msaldodolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_msaldodolares,
#   (t1.Master_mconsumospesos - lag(t1.Master_mconsumospesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_mconsumospesos - lag(t1.Master_mconsumospesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_mconsumospesos,
#   (t1.Master_mconsumosdolares - lag(t1.Master_mconsumosdolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_mconsumosdolares - lag(t1.Master_mconsumosdolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_mconsumosdolares,
#   (t1.Master_mlimitecompra - lag(t1.Master_mlimitecompra, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_mlimitecompra - lag(t1.Master_mlimitecompra, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_mlimitecompra,
#   (t1.Master_madelantopesos - lag(t1.Master_madelantopesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_madelantopesos - lag(t1.Master_madelantopesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_madelantopesos,
#   (t1.Master_madelantodolares - lag(t1.Master_madelantodolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_madelantodolares - lag(t1.Master_madelantodolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_madelantodolares,
#   (t1.Master_fultimo_cierre - lag(t1.Master_fultimo_cierre, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_fultimo_cierre - lag(t1.Master_fultimo_cierre, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_fultimo_cierre,
#   (t1.Master_mpagado - lag(t1.Master_mpagado, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_mpagado - lag(t1.Master_mpagado, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_mpagado,
#   (t1.Master_mpagospesos - lag(t1.Master_mpagospesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_mpagospesos - lag(t1.Master_mpagospesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_mpagospesos,
#   (t1.Master_mpagosdolares - lag(t1.Master_mpagosdolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_mpagosdolares - lag(t1.Master_mpagosdolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_mpagosdolares,
#   (t1.Master_mconsumototal - lag(t1.Master_mconsumototal, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_mconsumototal - lag(t1.Master_mconsumototal, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_mconsumototal,
#   (t1.Master_cconsumos - lag(t1.Master_cconsumos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_cconsumos - lag(t1.Master_cconsumos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_cconsumos,
#   (t1.Master_cadelantosefectivo - lag(t1.Master_cadelantosefectivo, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_cadelantosefectivo - lag(t1.Master_cadelantosefectivo, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_cadelantosefectivo,
#   (t1.Master_mpagominimo - lag(t1.Master_mpagominimo, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Master_mpagominimo - lag(t1.Master_mpagominimo, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Master_mpagominimo,
#   (t1.Visa_delinquency - lag(t1.Visa_delinquency, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_delinquency - lag(t1.Visa_delinquency, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_delinquency,
#   (t1.Visa_mfinanciacion_limite - lag(t1.Visa_mfinanciacion_limite, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_mfinanciacion_limite - lag(t1.Visa_mfinanciacion_limite, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_mfinanciacion_limite,
#   (t1.Visa_Fvencimiento - lag(t1.Visa_Fvencimiento, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_Fvencimiento - lag(t1.Visa_Fvencimiento, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_Fvencimiento,
#   (t1.Visa_Finiciomora - lag(t1.Visa_Finiciomora, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_Finiciomora - lag(t1.Visa_Finiciomora, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_Finiciomora,
#   (t1.Visa_msaldototal - lag(t1.Visa_msaldototal, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_msaldototal - lag(t1.Visa_msaldototal, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_msaldototal,
#   (t1.Visa_msaldopesos - lag(t1.Visa_msaldopesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_msaldopesos - lag(t1.Visa_msaldopesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_msaldopesos,
#   (t1.Visa_msaldodolares - lag(t1.Visa_msaldodolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_msaldodolares - lag(t1.Visa_msaldodolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_msaldodolares,
#   (t1.Visa_mconsumospesos - lag(t1.Visa_mconsumospesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_mconsumospesos - lag(t1.Visa_mconsumospesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_mconsumospesos,
#   (t1.Visa_mconsumosdolares - lag(t1.Visa_mconsumosdolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_mconsumosdolares - lag(t1.Visa_mconsumosdolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_mconsumosdolares,
#   (t1.Visa_mlimitecompra - lag(t1.Visa_mlimitecompra, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_mlimitecompra - lag(t1.Visa_mlimitecompra, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_mlimitecompra,
#   (t1.Visa_madelantopesos - lag(t1.Visa_madelantopesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_madelantopesos - lag(t1.Visa_madelantopesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_madelantopesos,
#   (t1.Visa_madelantodolares - lag(t1.Visa_madelantodolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_madelantodolares - lag(t1.Visa_madelantodolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_madelantodolares,
#   (t1.Visa_mpagado - lag(t1.Visa_mpagado, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_mpagado - lag(t1.Visa_mpagado, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_mpagado,
#   (t1.Visa_mpagospesos - lag(t1.Visa_mpagospesos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_mpagospesos - lag(t1.Visa_mpagospesos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_mpagospesos,
#   (t1.Visa_mpagosdolares - lag(t1.Visa_mpagosdolares, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_mpagosdolares - lag(t1.Visa_mpagosdolares, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_mpagosdolares,
#   (t1.Visa_mconsumototal - lag(t1.Visa_mconsumototal, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_mconsumototal - lag(t1.Visa_mconsumototal, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_mconsumototal,
#   (t1.Visa_cconsumos - lag(t1.Visa_cconsumos, 1) over (partition by t1.numero_de_cliente order by t1.foto_mes)) + (t1.Visa_cconsumos - lag(t1.Visa_cconsumos, 2) over (partition by t1.numero_de_cliente order by t1.foto_mes)) as sum_deltas_Visa_cconsumos,
#   MAX(t1.active_quarter) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_active_quarter,
#   MIN(t1.active_quarter) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_active_quarter,
#   MAX(t1.mrentabilidad) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mrentabilidad,
#   MIN(t1.mrentabilidad) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mrentabilidad,
#   MAX(t1.mrentabilidad_annual) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mrentabilidad_annual,
#   MIN(t1.mrentabilidad_annual) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mrentabilidad_annual,
#   MAX(t1.mcomisiones) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mcomisiones,
#   MIN(t1.mcomisiones) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mcomisiones,
#   MAX(t1.mactivos_margen) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mactivos_margen,
#   MIN(t1.mactivos_margen) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mactivos_margen,
#   MAX(t1.mpasivos_margen) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mpasivos_margen,
#   MIN(t1.mpasivos_margen) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mpasivos_margen,
#   MAX(t1.cproductos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_cproductos,
#   MIN(t1.cproductos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_cproductos,
#   MAX(t1.ccuenta_corriente) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ccuenta_corriente,
#   MIN(t1.ccuenta_corriente) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ccuenta_corriente,
#   MAX(t1.mcuenta_corriente_adicional) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mcuenta_corriente_adicional,
#   MIN(t1.mcuenta_corriente_adicional) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mcuenta_corriente_adicional,
#   MAX(t1.mcuenta_corriente) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mcuenta_corriente,
#   MIN(t1.mcuenta_corriente) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mcuenta_corriente,
#   MAX(t1.ccaja_ahorro) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ccaja_ahorro,
#   MIN(t1.ccaja_ahorro) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ccaja_ahorro,
#   MAX(t1.mcaja_ahorro) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mcaja_ahorro,
#   MIN(t1.mcaja_ahorro) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mcaja_ahorro,
#   MAX(t1.mcaja_ahorro_adicional) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mcaja_ahorro_adicional,
#   MIN(t1.mcaja_ahorro_adicional) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mcaja_ahorro_adicional,
#   MAX(t1.mcaja_ahorro_dolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mcaja_ahorro_dolares,
#   MIN(t1.mcaja_ahorro_dolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mcaja_ahorro_dolares,
#   MAX(t1.cdescubierto_preacordado) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_cdescubierto_preacordado,
#   MIN(t1.cdescubierto_preacordado) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_cdescubierto_preacordado,
#   MAX(t1.mcuentas_saldo) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mcuentas_saldo,
#   MIN(t1.mcuentas_saldo) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mcuentas_saldo,
#   MAX(t1.ctarjeta_debito) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ctarjeta_debito,
#   MIN(t1.ctarjeta_debito) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ctarjeta_debito,
#   MAX(t1.ctarjeta_debito_transacciones) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ctarjeta_debito_transacciones,
#   MIN(t1.ctarjeta_debito_transacciones) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ctarjeta_debito_transacciones,
#   MAX(t1.mautoservicio) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mautoservicio,
#   MIN(t1.mautoservicio) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mautoservicio,
#   MAX(t1.ctarjeta_visa) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ctarjeta_visa,
#   MIN(t1.ctarjeta_visa) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ctarjeta_visa,
#   MAX(t1.ctarjeta_visa_transacciones) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ctarjeta_visa_transacciones,
#   MIN(t1.ctarjeta_visa_transacciones) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ctarjeta_visa_transacciones,
#   MAX(t1.mtarjeta_visa_consumo) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mtarjeta_visa_consumo,
#   MIN(t1.mtarjeta_visa_consumo) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mtarjeta_visa_consumo,
#   MAX(t1.ctarjeta_master) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ctarjeta_master,
#   MIN(t1.ctarjeta_master) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ctarjeta_master,
#   MAX(t1.ctarjeta_master_transacciones) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ctarjeta_master_transacciones,
#   MIN(t1.ctarjeta_master_transacciones) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ctarjeta_master_transacciones,
#   MAX(t1.mtarjeta_master_consumo) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mtarjeta_master_consumo,
#   MIN(t1.mtarjeta_master_consumo) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mtarjeta_master_consumo,
#   MAX(t1.cplazo_fijo) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_cplazo_fijo,
#   MIN(t1.cplazo_fijo) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_cplazo_fijo,
#   MAX(t1.mplazo_fijo_dolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mplazo_fijo_dolares,
#   MIN(t1.mplazo_fijo_dolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mplazo_fijo_dolares,
#   MAX(t1.mplazo_fijo_pesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mplazo_fijo_pesos,
#   MIN(t1.mplazo_fijo_pesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mplazo_fijo_pesos,
#   MAX(t1.cinversion1) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_cinversion1,
#   MIN(t1.cinversion1) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_cinversion1,
#   MAX(t1.minversion1_pesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_minversion1_pesos,
#   MIN(t1.minversion1_pesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_minversion1_pesos,
#   MAX(t1.minversion1_dolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_minversion1_dolares,
#   MIN(t1.minversion1_dolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_minversion1_dolares,
#   MAX(t1.cinversion2) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_cinversion2,
#   MIN(t1.cinversion2) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_cinversion2,
#   MAX(t1.minversion2) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_minversion2,
#   MIN(t1.minversion2) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_minversion2,
#   MAX(t1.ccaja_seguridad) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ccaja_seguridad,
#   MIN(t1.ccaja_seguridad) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ccaja_seguridad,
#   MAX(t1.cpayroll_trx) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_cpayroll_trx,
#   MIN(t1.cpayroll_trx) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_cpayroll_trx,
#   MAX(t1.mpayroll) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mpayroll,
#   MIN(t1.mpayroll) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mpayroll,
#   MAX(t1.mpayroll2) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mpayroll2,
#   MIN(t1.mpayroll2) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mpayroll2,
#   MAX(t1.cpayroll2_trx) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_cpayroll2_trx,
#   MIN(t1.cpayroll2_trx) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_cpayroll2_trx,
#   MAX(t1.ccuenta_debitos_automaticos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ccuenta_debitos_automaticos,
#   MIN(t1.ccuenta_debitos_automaticos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ccuenta_debitos_automaticos,
#   MAX(t1.mcuenta_debitos_automaticos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mcuenta_debitos_automaticos,
#   MIN(t1.mcuenta_debitos_automaticos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mcuenta_debitos_automaticos,
#   MAX(t1.ctarjeta_visa_debitos_automaticos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ctarjeta_visa_debitos_automaticos,
#   MIN(t1.ctarjeta_visa_debitos_automaticos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ctarjeta_visa_debitos_automaticos,
#   MAX(t1.mttarjeta_visa_debitos_automaticos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mttarjeta_visa_debitos_automaticos,
#   MIN(t1.mttarjeta_visa_debitos_automaticos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mttarjeta_visa_debitos_automaticos,
#   MAX(t1.ctarjeta_master_debitos_automaticos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ctarjeta_master_debitos_automaticos,
#   MIN(t1.ctarjeta_master_debitos_automaticos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ctarjeta_master_debitos_automaticos,
#   MAX(t1.mttarjeta_master_debitos_automaticos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mttarjeta_master_debitos_automaticos,
#   MIN(t1.mttarjeta_master_debitos_automaticos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mttarjeta_master_debitos_automaticos,
#   MAX(t1.cpagodeservicios) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_cpagodeservicios,
#   MIN(t1.cpagodeservicios) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_cpagodeservicios,
#   MAX(t1.mpagodeservicios) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mpagodeservicios,
#   MIN(t1.mpagodeservicios) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mpagodeservicios,
#   MAX(t1.cpagomiscuentas) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_cpagomiscuentas,
#   MIN(t1.cpagomiscuentas) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_cpagomiscuentas,
#   MAX(t1.mpagomiscuentas) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mpagomiscuentas,
#   MIN(t1.mpagomiscuentas) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mpagomiscuentas,
#   MAX(t1.ccajeros_propios_descuentos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ccajeros_propios_descuentos,
#   MIN(t1.ccajeros_propios_descuentos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ccajeros_propios_descuentos,
#   MAX(t1.mcajeros_propios_descuentos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mcajeros_propios_descuentos,
#   MIN(t1.mcajeros_propios_descuentos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mcajeros_propios_descuentos,
#   MAX(t1.ctarjeta_visa_descuentos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ctarjeta_visa_descuentos,
#   MIN(t1.ctarjeta_visa_descuentos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ctarjeta_visa_descuentos,
#   MAX(t1.mtarjeta_visa_descuentos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mtarjeta_visa_descuentos,
#   MIN(t1.mtarjeta_visa_descuentos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mtarjeta_visa_descuentos,
#   MAX(t1.ctarjeta_master_descuentos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ctarjeta_master_descuentos,
#   MIN(t1.ctarjeta_master_descuentos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ctarjeta_master_descuentos,
#   MAX(t1.mtarjeta_master_descuentos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mtarjeta_master_descuentos,
#   MIN(t1.mtarjeta_master_descuentos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mtarjeta_master_descuentos,
#   MAX(t1.ccomisiones_mantenimiento) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ccomisiones_mantenimiento,
#   MIN(t1.ccomisiones_mantenimiento) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ccomisiones_mantenimiento,
#   MAX(t1.mcomisiones_mantenimiento) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mcomisiones_mantenimiento,
#   MIN(t1.mcomisiones_mantenimiento) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mcomisiones_mantenimiento,
#   MAX(t1.ccomisiones_otras) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ccomisiones_otras,
#   MIN(t1.ccomisiones_otras) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ccomisiones_otras,
#   MAX(t1.mcomisiones_otras) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mcomisiones_otras,
#   MIN(t1.mcomisiones_otras) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mcomisiones_otras,
#   MAX(t1.cforex) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_cforex,
#   MIN(t1.cforex) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_cforex,
#   MAX(t1.cforex_buy) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_cforex_buy,
#   MIN(t1.cforex_buy) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_cforex_buy,
#   MAX(t1.mforex_buy) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mforex_buy,
#   MIN(t1.mforex_buy) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mforex_buy,
#   MAX(t1.cforex_sell) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_cforex_sell,
#   MIN(t1.cforex_sell) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_cforex_sell,
#   MAX(t1.mforex_sell) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_mforex_sell,
#   MIN(t1.mforex_sell) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_mforex_sell,
#   MAX(t1.ccajas_extracciones) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ccajas_extracciones,
#   MIN(t1.ccajas_extracciones) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ccajas_extracciones,
#   MAX(t1.ccajas_otras) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ccajas_otras,
#   MIN(t1.ccajas_otras) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ccajas_otras,
#   MAX(t1.catm_trx) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_catm_trx,
#   MIN(t1.catm_trx) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_catm_trx,
#   MAX(t1.matm) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_matm,
#   MIN(t1.matm) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_matm,
#   MAX(t1.ctrx_quarter) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_ctrx_quarter,
#   MIN(t1.ctrx_quarter) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_ctrx_quarter,
#   MAX(t1.cmobile_app_trx) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_cmobile_app_trx,
#   MIN(t1.cmobile_app_trx) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_cmobile_app_trx,
#   MAX(t1.Master_delinquency) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_delinquency,
#   MIN(t1.Master_delinquency) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_delinquency,
#   MAX(t1.Master_mfinanciacion_limite) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_mfinanciacion_limite,
#   MIN(t1.Master_mfinanciacion_limite) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_mfinanciacion_limite,
#   MAX(t1.Master_Fvencimiento) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_Fvencimiento,
#   MIN(t1.Master_Fvencimiento) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_Fvencimiento,
#   MAX(t1.Master_Finiciomora) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_Finiciomora,
#   MIN(t1.Master_Finiciomora) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_Finiciomora,
#   MAX(t1.Master_msaldototal) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_msaldototal,
#   MIN(t1.Master_msaldototal) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_msaldototal,
#   MAX(t1.Master_msaldopesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_msaldopesos,
#   MIN(t1.Master_msaldopesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_msaldopesos,
#   MAX(t1.Master_msaldodolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_msaldodolares,
#   MIN(t1.Master_msaldodolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_msaldodolares,
#   MAX(t1.Master_mconsumospesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_mconsumospesos,
#   MIN(t1.Master_mconsumospesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_mconsumospesos,
#   MAX(t1.Master_mconsumosdolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_mconsumosdolares,
#   MIN(t1.Master_mconsumosdolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_mconsumosdolares,
#   MAX(t1.Master_mlimitecompra) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_mlimitecompra,
#   MIN(t1.Master_mlimitecompra) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_mlimitecompra,
#   MAX(t1.Master_madelantopesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_madelantopesos,
#   MIN(t1.Master_madelantopesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_madelantopesos,
#   MAX(t1.Master_madelantodolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_madelantodolares,
#   MIN(t1.Master_madelantodolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_madelantodolares,
#   MAX(t1.Master_fultimo_cierre) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_fultimo_cierre,
#   MIN(t1.Master_fultimo_cierre) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_fultimo_cierre,
#   MAX(t1.Master_mpagado) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_mpagado,
#   MIN(t1.Master_mpagado) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_mpagado,
#   MAX(t1.Master_mpagospesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_mpagospesos,
#   MIN(t1.Master_mpagospesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_mpagospesos,
#   MAX(t1.Master_mpagosdolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_mpagosdolares,
#   MIN(t1.Master_mpagosdolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_mpagosdolares,
#   MAX(t1.Master_fechaalta) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_fechaalta,
#   MIN(t1.Master_fechaalta) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_fechaalta,
#   MAX(t1.Master_mconsumototal) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_mconsumototal,
#   MIN(t1.Master_mconsumototal) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_mconsumototal,
#   MAX(t1.Master_cconsumos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_cconsumos,
#   MIN(t1.Master_cconsumos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_cconsumos,
#   MAX(t1.Master_cadelantosefectivo) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Master_cadelantosefectivo,
#   MIN(t1.Master_cadelantosefectivo) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Master_cadelantosefectivo,
#   MAX(t1.Visa_delinquency) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_delinquency,
#   MIN(t1.Visa_delinquency) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_delinquency,
#   MAX(t1.Visa_mfinanciacion_limite) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_mfinanciacion_limite,
#   MIN(t1.Visa_mfinanciacion_limite) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_mfinanciacion_limite,
#   MAX(t1.Visa_msaldototal) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_msaldototal,
#   MIN(t1.Visa_msaldototal) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_msaldototal,
#   MAX(t1.Visa_msaldopesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_msaldopesos,
#   MIN(t1.Visa_msaldopesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_msaldopesos,
#   MAX(t1.Visa_msaldodolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_msaldodolares,
#   MIN(t1.Visa_msaldodolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_msaldodolares,
#   MAX(t1.Visa_mconsumospesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_mconsumospesos,
#   MIN(t1.Visa_mconsumospesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_mconsumospesos,
#   MAX(t1.Visa_mconsumosdolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_mconsumosdolares,
#   MIN(t1.Visa_mconsumosdolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_mconsumosdolares,
#   MAX(t1.Visa_mlimitecompra) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_mlimitecompra,
#   MIN(t1.Visa_mlimitecompra) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_mlimitecompra,
#   MAX(t1.Visa_madelantopesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_madelantopesos,
#   MIN(t1.Visa_madelantopesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_madelantopesos,
#   MAX(t1.Visa_madelantodolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_madelantodolares,
#   MIN(t1.Visa_madelantodolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_madelantodolares,
#   MAX(t1.Visa_mpagado) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_mpagado,
#   MIN(t1.Visa_mpagado) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_mpagado,
#   MAX(t1.Visa_mpagospesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_mpagospesos,
#   MIN(t1.Visa_mpagospesos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_mpagospesos,
#   MAX(t1.Visa_mpagosdolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_mpagosdolares,
#   MIN(t1.Visa_mpagosdolares) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_mpagosdolares,
#   MAX(t1.Visa_mconsumototal) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_mconsumototal,
#   MIN(t1.Visa_mconsumototal) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_mconsumototal,
#   MAX(t1.Visa_cconsumos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as max_Visa_cconsumos,
#   MIN(t1.Visa_cconsumos) OVER (partition by t1.numero_de_cliente order by t1.foto_mes) as min_Visa_cconsumos,
#
# FROM competencia_01_fe t1
# ORDER BY t1.numero_de_cliente, t1.foto_mes;
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# CREATE OR REPLACE TABLE competencia_01_fe AS
# SELECT
#     *,
#     random() as pajarito_1,
#     random() as pajarito_2,
#     random() as pajarito_3,
#     random() as pajarito_4,
#     random() as pajarito_5,
#     random() as pajarito_6,
#     random() as pajarito_7,
#     random() as pajarito_8,
#     random() as pajarito_9,
#     random() as pajarito_10,
#     random() as pajarito_11,
#     random() as pajarito_12,
#     random() as pajarito_13,
#     random() as pajarito_14,
#     random() as pajarito_15,
# FROM competencia_01_fe;
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %sql COPY competencia_01_fe TO 'competencia_01_fe.csv' (FORMAT CSV, HEADER)

# !cp competencia_01_fe.csv "/content/drive/MyDrive/maestria/dm-eyf/datos/"
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
